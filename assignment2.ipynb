# %%
import csv, numpy as np

# %%
def read_csv_as_lists(filename):
    data = []
    # Open the file in read mode ('r') with proper encoding
    with open(filename, mode='r', encoding='utf-8', newline='') as file:
        # Create a CSV reader object
        csv_reader = csv.reader(file)
        
        # Optionally skip the header row
        # next(csv_reader, None) 

        # Iterate over each row in the file
        for row in csv_reader:
            data.append(row)
            
    return data

# %%
data = read_csv_as_lists('framingham.csv')

# %%
df = np.array(data)

# %%
features = df[0:1].astype(str)

# %%
features_vals = df[1:]
features_vals = features_vals.replace("NA", np.NaN).astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 2
#       1 features_vals = df[1:]
# ----> 2 features_vals = features_vals.replace("NA", np.NaN).astype(float)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'replace'

# %%
features_val
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 features_vals.type(float)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'type'

# %%
features, features_vals
# Out:
# (array([['male', 'age', 'education', 'currentSmoker', 'cigsPerDay',
#          'BPMeds', 'prevalentStroke', 'prevalentHyp', 'diabetes',
#          'totChol', 'sysBP', 'diaBP', 'BMI', 'heartRate', 'glucose',
#          'TenYearCHD']], dtype='<U15'),
#  array([['1', '39', '4', ..., '80', '77', '0'],
#         ['0', '46', '2', ..., '95', '76', '0'],
#         ['1', '48', '1', ..., '75', '70', '0'],
#         ...,
#         ['0', '48', '2', ..., '84', '86', '0'],
#         ['0', '44', '1', ..., '86', 'NA', '0'],
#         ['0', '52', '2', ..., '80', '107', '0']],
#        shape=(4238, 16), dtype='<U15'))

# %%
df[0:5]
# Out:
# array([['male', 'age', 'education', 'currentSmoker', 'cigsPerDay',
#         'BPMeds', 'prevalentStroke', 'prevalentHyp', 'diabetes',
#         'totChol', 'sysBP', 'diaBP', 'BMI', 'heartRate', 'glucose',
#         'TenYearCHD'],
#        ['1', '39', '4', '0', '0', '0', '0', '0', '0', '195', '106', '70',
#         '26.97', '80', '77', '0'],
#        ['0', '46', '2', '0', '0', '0', '0', '0', '0', '250', '121', '81',
#         '28.73', '95', '76', '0'],
#        ['1', '48', '1', '1', '20', '0', '0', '0', '0', '245', '127.5',
#         '80', '25.34', '75', '70', '0'],
#        ['0', '61', '3', '1', '30', '0', '0', '1', '0', '225', '150',
#         '95', '28.58', '65', '103', '1']], dtype='<U15')

# %%
# df[len(df[0]) - 1 : len(df[0])]
Y  = df[1:,15]

# %%
features_vals[237:,0:15]
# Out:
# array([['0', '55', '1', ..., '26.89', '75', '80'],
#        ['0', '55', '3', ..., '27.15', '75', '97'],
#        ['1', '40', '3', ..., '26.32', '95', '60'],
#        ...,
#        ['0', '48', '2', ..., '22', '84', '86'],
#        ['0', '44', '1', ..., '19.16', '86', 'NA'],
#        ['0', '52', '2', ..., '21.47', '80', '107']],
#       shape=(4001, 15), dtype='<U15')

# %%
features[0:,15],features_vals
# Out:
# (array(['TenYearCHD'], dtype='<U15'),
#  array([['1', '39', '4', ..., '80', '77', '0'],
#         ['0', '46', '2', ..., '95', '76', '0'],
#         ['1', '48', '1', ..., '75', '70', '0'],
#         ...,
#         ['0', '48', '2', ..., '84', '86', '0'],
#         ['0', '44', '1', ..., '86', 'NA', '0'],
#         ['0', '52', '2', ..., '80', '107', '0']],
#        shape=(4238, 16), dtype='<U15'))

# %%
training_split = 0.8
training_labels = Y[0:round(Y.shape[0] * training_split)]
testing_labels =  Y[round(Y.shape[0] * training_split):]


training_data = features_vals[0:round(features_vals.shape[0] * training_split), 0:15]
testing_data = features_vals[round(features_vals.shape[0] * training_split):, 0:15]

# %%
training_labels.shape, testing_labels.shape
# Out:
# ((3390,), (848,))

# %%
training_data.shape, testing_data.shape
# Out:
# ((3390, 15), (848, 15))

# %%
class Neuron:
    def __init__(self,nin):
        self.w = [Value(random.uniform(-1,1)) for _ in range(nin)]
        self.b = Value(random.uniform(-1,1))
    def __call__(self,x):
        act = sum((wi * xi for wi, xi in zip(self.w,x)),self.b)
        out = np.tanh(act)
        return out


    def paramenters(self):
        return self.w  [self.b]


class Layer:
    def __init__(self,nin,nout):
        self.neurons = [Neuron(nin) for _ in range(nout)]
        
    def __call__(self,x):
        outs = [n(x) for n in self.neurons]
        return outs[0] if len(outs) == 1 else outs

    def parameters(self):
        return [p for neuron in self.neurons for p in neuron.parameters()]


class MLP:

    def __init__(self,nin,nouts):
        sz = [nin] + nouts
        self.layers = [Layer(sz[i],sz[i+1]) for i in range(len(nouts))]

    def __call__(self,x):
        for layer in self.layers:
            x = layer(x)
        return x

    def parameters(self):
        return [p for layer in self.layers for p in layer.parameters()]

# %%
np.tanh(1)
# Out:
# np.float64(0.7615941559557649)
